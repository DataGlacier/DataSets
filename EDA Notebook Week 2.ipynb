# %%
import pandas as pd

# %% [markdown]
# Loaded Python libraries and csv files into a tabular dataframe via pandas for Exploratory Data Analysis.

# %%
cab_data = pd.read_csv('Cab_Data.csv')

# %%
city_data = pd.read_csv('City.csv')

# %%
customer_data = pd.read_csv('Customer_ID.csv')

# %%
transaction_data = pd.read_csv('Transaction_ID.csv')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# Wanted general information and statistics for the different dataframes.

# %%
print(cab_data)
# Out:
#         Transaction ID  Date of Travel     Company           City  \
# 0             10000011           42377    Pink Cab     ATLANTA GA
# 1             10000012           42375    Pink Cab     ATLANTA GA
# 2             10000013           42371    Pink Cab     ATLANTA GA
# 3             10000014           42376    Pink Cab     ATLANTA GA
# 4             10000015           42372    Pink Cab     ATLANTA GA
# ...                ...             ...         ...            ...
# 359387        10440101           43108  Yellow Cab  WASHINGTON DC
# 359388        10440104           43104  Yellow Cab  WASHINGTON DC
# 359389        10440105           43105  Yellow Cab  WASHINGTON DC
# 359390        10440106           43105  Yellow Cab  WASHINGTON DC
# 359391        10440107           43102  Yellow Cab  WASHINGTON DC
#
#         KM Travelled  Price Charged  Cost of Trip
# 0              30.45         370.95        313.63
# 1              28.62         358.52        334.85
# ...

# %%
cab_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 359392 entries, 0 to 359391
# Data columns (total 7 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  359392 non-null  int64
#  1   Date of Travel  359392 non-null  int64
#  2   Company         359392 non-null  object
#  3   City            359392 non-null  object
#  4   KM Travelled    359392 non-null  float64
#  5   Price Charged   359392 non-null  float64
#  6   Cost of Trip    359392 non-null  float64
# dtypes: float64(3), int64(2), object(2)
# memory usage: 19.2+ MB

# %%
cab_data.describe()
# Out:
#        Transaction ID  Date of Travel   KM Travelled  Price Charged  \
# count    3.593920e+05   359392.000000  359392.000000  359392.000000
# mean     1.022076e+07    42964.067998      22.567254     423.443311
# std      1.268058e+05      307.467197      12.233526     274.378911
# min      1.000001e+07    42371.000000       1.900000      15.600000
# 25%      1.011081e+07    42697.000000      12.000000     206.437500
# 50%      1.022104e+07    42988.000000      22.440000     386.360000
# 75%      1.033094e+07    43232.000000      32.960000     583.660000
# max      1.044011e+07    43465.000000      48.000000    2048.030000
#
#         Cost of Trip
# count  359392.000000
# mean      286.190113
# std       157.993661
# min        19.000000
# 25%       151.200000
# 50%       282.480000
# 75%       413.683200
# max       691.200000

# %%
print(city_data)
# Out:
#                 City   Population      Users
# 0        NEW YORK NY   8,405,837    302,149
# 1         CHICAGO IL   1,955,130    164,468
# 2     LOS ANGELES CA   1,595,037    144,132
# 3           MIAMI FL   1,339,155     17,675
# 4     SILICON VALLEY   1,177,609     27,247
# 5      ORANGE COUNTY   1,030,185     12,994
# 6       SAN DIEGO CA     959,307     69,995
# 7         PHOENIX AZ     943,999      6,133
# 8          DALLAS TX     942,908     22,157
# 9         ATLANTA GA     814,885     24,701
# 10         DENVER CO     754,233     12,421
# 11         AUSTIN TX     698,371     14,978
# 12        SEATTLE WA     671,238     25,063
# 13         TUCSON AZ     631,442      5,712
# 14  SAN FRANCISCO CA     629,591    213,609
# 15     SACRAMENTO CA     545,776      7,044
# 16     PITTSBURGH PA     542,085      3,643
# 17     WASHINGTON DC     418,859    127,001
# 18      NASHVILLE TN     327,225      9,270
# 19         BOSTON MA     248,968     80,021

# %%
city_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   City        20 non-null     object
#  1   Population  20 non-null     object
#  2   Users       20 non-null     object
# dtypes: object(3)
# memory usage: 608.0+ bytes

# %%
city_data.describe()
# Out:
#                City   Population      Users
# count            20           20         20
# unique           20           20         20
# top     NEW YORK NY   8,405,837    302,149
# freq              1            1          1

# %%
print(customer_data)
# Out:
#        Customer ID  Gender  Age  Income (USD/Month)
# 0            29290    Male   28               10813
# 1            27703    Male   27                9237
# 2            28712    Male   53               11242
# 3            28020    Male   23               23327
# 4            27182    Male   33                8536
# ...            ...     ...  ...                 ...
# 49166        12490    Male   33               18713
# 49167        14971    Male   30               15346
# 49168        41414    Male   38                3960
# 49169        41677    Male   23               19454
# 49170        39761  Female   32               10128
#
# [49171 rows x 4 columns]

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49171 entries, 0 to 49170
# Data columns (total 4 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         49171 non-null  int64
#  1   Gender              49171 non-null  object
#  2   Age                 49171 non-null  int64
#  3   Income (USD/Month)  49171 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 1.5+ MB

# %%
customer_data.describe()
# Out:
#         Customer ID           Age  Income (USD/Month)
# count  49171.000000  49171.000000        49171.000000
# mean   28398.252283     35.363121        15015.631856
# std    17714.137333     12.599066         8002.208253
# min        1.000000     18.000000         2000.000000
# 25%    12654.500000     25.000000         8289.500000
# 50%    27631.000000     33.000000        14656.000000
# 75%    43284.500000     42.000000        21035.000000
# max    60000.000000     65.000000        35000.000000

# %%
print(transaction_data)
# Out:
#         Transaction ID  Customer ID Payment_Mode
# 0             10000011        29290         Card
# 1             10000012        27703         Card
# 2             10000013        28712         Cash
# 3             10000014        28020         Cash
# 4             10000015        27182         Card
# ...                ...          ...          ...
# 440093        10440104        53286         Cash
# 440094        10440105        52265         Cash
# 440095        10440106        52175         Card
# 440096        10440107        52917         Card
# 440097        10440108        51587         Card
#
# [440098 rows x 3 columns]

# %%
transaction_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440098 entries, 0 to 440097
# Data columns (total 3 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Transaction ID  440098 non-null  int64
#  1   Customer ID     440098 non-null  int64
#  2   Payment_Mode    440098 non-null  object
# dtypes: int64(2), object(1)
# memory usage: 10.1+ MB

# %%
transaction_data.describe()
# Out:
#        Transaction ID    Customer ID
# count    4.400980e+05  440098.000000
# mean     1.022006e+07   23619.513120
# std      1.270455e+05   21195.549816
# min      1.000001e+07       1.000000
# 25%      1.011004e+07    3530.000000
# 50%      1.022006e+07   15168.000000
# 75%      1.033008e+07   43884.000000
# max      1.044011e+07   60000.000000

# %% [markdown]
# **Started data cleaning process by checking for duplicates.**

# %%
cab_data.duplicated().sum()
# Out:
# 0

# %%
city_data.duplicated().sum()
# Out:
# 0

# %%
customer_data.duplicated().sum()
# Out:
# 0

# %%
transaction_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# **Merged cab_data with transaction_data based on Transaction ID, then merged customer_data into the first merged datasets to create a new master dataframe.**

# %%
merged_data = pd.merge(transaction_data, cab_data, on ='Transaction ID', how ='left')

new_data = pd.merge(merged_data, customer_data, on ='Customer ID', how ='left')

# %% [raw]
# new_data.head()

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 440098 entries, 0 to 440097
# Data columns (total 12 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   Transaction ID      440098 non-null  int64
#  1   Customer ID         440098 non-null  int64
#  2   Payment_Mode        440098 non-null  object
#  3   Date of Travel      359392 non-null  float64
#  4   Company             359392 non-null  object
#  5   City                359392 non-null  object
#  6   KM Travelled        359392 non-null  float64
#  7   Price Charged       359392 non-null  float64
#  8   Cost of Trip        359392 non-null  float64
#  9   Gender              440098 non-null  object
#  10  Age                 440098 non-null  int64
#  11  Income (USD/Month)  440098 non-null  int64
# dtypes: float64(4), int64(4), object(4)
# memory usage: 43.6+ MB

# %%
new_data.describe()
# Out:
#        Transaction ID    Customer ID  Date of Travel   KM Travelled  \
# count    4.400980e+05  440098.000000   359392.000000  359392.000000
# mean     1.022006e+07   23619.513120    42964.067998      22.567254
# std      1.270455e+05   21195.549816      307.467197      12.233526
# min      1.000001e+07       1.000000    42371.000000       1.900000
# 25%      1.011004e+07    3530.000000    42697.000000      12.000000
# 50%      1.022006e+07   15168.000000    42988.000000      22.440000
# 75%      1.033008e+07   43884.000000    43232.000000      32.960000
# max      1.044011e+07   60000.000000    43465.000000      48.000000
#
#        Price Charged   Cost of Trip            Age  Income (USD/Month)
# count  359392.000000  359392.000000  440098.000000       440098.000000
# mean      423.443311     286.190113      35.360197        15092.181989
# std       274.378911     157.993661      12.582668         7987.309505
# min        15.600000      19.000000      18.000000         2000.000000
# ...

# %% [markdown]
# **Hypothesis 1: 35-45 year olds in major cities around the United States create the most profit for cab companies. Yellow cab will appear to be the more profitable company.**

# %%
# Filtered the dataframe to include ages 35-45 and exclude incomes from 0-10000.
filtered_df = new_data[(new_data['Age'] >= 35) & (new_data['Age'] <= 45) & (new_data['Income (USD/Month)'] < 0) | (new_data['Income (USD/Month)'] > 10000)]

# Created a histogram of the income variable.
plt.hist(filtered_df['Income (USD/Month)'], bins = 10, color = 'orange')
plt.xlabel('Income (USD/Month)')
plt.ylabel('Frequency')
plt.title('Histogram of Income')
plt.show()

# Sought to see the distribution of income for the sample collected. To see different levels
# of income can give insight to where cab drivers should be in terms of location to pick up
# customers based off income of that area.

# %%
# Got the counts of each Customer ID.
customer_counts = filtered_df['Customer ID'].value_counts()

# Create a scatter plot of the Customer ID transaction counts.
plt.scatter(customer_counts.index, customer_counts.values, color = 'black')
plt.xlabel('Customer ID')
plt.ylabel('Number of Transactions')
plt.title('Scatter Plot of Customer Transactions')
plt.show()

# Able to see how many transactions each Customer ID had from the filtered dataframe.
# Allows me to see how often a customer would seek to ride in a taxi service and which
# Customer ID group specifically.

# %%
# Defined the customer ID ranges.
customer_id_ranges = [range(0, 9001), range(17000, 22001), range(42000, 47001), range(52000, 56001), range(51000, 61001)]

# Combined the customer ID ranges into a single list.
customer_ids = [customer_id for customer_id_range in customer_id_ranges for customer_id in customer_id_range]

# Filtered the dataframe based on the selected customer IDs.
selected_data = new_data[new_data['Customer ID'].isin(customer_ids)]

# Selected the 'Price Charged' and 'City' columns.
selected_columns = ['Price Charged', 'Company', 'City']
selected_data = selected_data[selected_columns]

print(selected_data)

# Wanted to see specifically each Customer ID's 'Price Charged' and 'City' in order to target
# those high transaction counts from each Customer ID.
# Out:
#         Price Charged     Company           City
# 8              191.61    Pink Cab      BOSTON MA
# 9              156.98    Pink Cab      BOSTON MA
# 10             570.83    Pink Cab      BOSTON MA
# 11             317.27    Pink Cab      BOSTON MA
# 12             158.01    Pink Cab      BOSTON MA
# ...               ...         ...            ...
# 440093         113.75  Yellow Cab  WASHINGTON DC
# 440094         437.07  Yellow Cab  WASHINGTON DC
# 440095         146.19  Yellow Cab  WASHINGTON DC
# 440096         191.58  Yellow Cab  WASHINGTON DC
# 440097            NaN         NaN            NaN
#
# [385705 rows x 3 columns]

# %%
# Grouped the data by 'Company' and calculated the sum of 'Price Charged'.
company_revenue = selected_data.groupby('Company')['Price Charged'].sum()

# Set the display format to print full numbers.
pd.options.display.float_format = '{:.2f}'.format

print(company_revenue)
# Out:
# Company
# Pink Cab      20659411.88
# Yellow Cab   110048677.34
# Name: Price Charged, dtype: float64

# %% [markdown]
# **Reults of Hypothesis 1: Seeing from customer_data.describe the mean age of people using the taxi services was 35.36, the 50% quartile being 33 years old, and the 75% quartile being 42 years old I decided a sample from ages 35-45 would capture a significant portion of the data, including the middle 50% (from the 25th percentile to the 75th percentile) and a portion beyond that. Using the above analysis we saw how many transactions the specific groups had, then below that we created a scatter plot to see frequency of transactions for the filtered Customer IDs. We were able aggregate the Price Charged total per company based off high frequency use Customer IDs to see their revenues. Seeing that the Pink Cab company was so much lower in revenue this hypothesis leads to investing in the Yellow Cab company.**

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **Hypothesis 2: By aggregating and grouping transaction IDs by city, it is expected that certain cities will exhibit a higher number of transactions compared to others. Using the city data, it is further hypothesized that the top 5-10 cities with the highest transaction volumes will also have a larger number of users. Additionally, through analyzing the profit metrics of the cab companies operating in these cities, it is anticipated that a better-performing cab company can be identified and recommended for improved service quality and customer experience.**

# %%
new_data.head(20)
# Out:
#     Transaction ID  Customer ID Payment_Mode  Date of Travel   Company  \
# 0         10000011        29290         Card        42377.00  Pink Cab
# 1         10000012        27703         Card        42375.00  Pink Cab
# 2         10000013        28712         Cash        42371.00  Pink Cab
# 3         10000014        28020         Cash        42376.00  Pink Cab
# 4         10000015        27182         Card        42372.00  Pink Cab
# 5         10000016        27318         Cash        42376.00  Pink Cab
# 6         10000017        33788         Card        42372.00  Pink Cab
# 7         10000018        34106         Card        42376.00  Pink Cab
# 8         10000019        59799         Cash        42381.00  Pink Cab
# 9         10000020        57982         Cash        42375.00  Pink Cab
# 10        10000021        58774         Cash        42380.00  Pink Cab
# 11        10000022        58627         Card        42375.00  Pink Cab
# ...

# %%
# Aggeregated 'Transaction ID' and then grouped by 'City'.
aggregated_tran_data = new_data.groupby('City')['Transaction ID'].count().reset_index()

# Ordered from highest to lowest based on 'Transaction ID'.
aggregated_tran_data = aggregated_tran_data.sort_values(by = 'Transaction ID', ascending = False)

print(aggregated_tran_data)
# Out:
#               City  Transaction ID
# 9      NEW YORK NY           99885
# 3       CHICAGO IL           56625
# 6   LOS ANGELES CA           48033
# 18   WASHINGTON DC           43737
# 2        BOSTON MA           29692
# 14    SAN DIEGO CA           20488
# 16  SILICON VALLEY            8519
# 15      SEATTLE WA            7997
# 0       ATLANTA GA            7557
# 4        DALLAS TX            7017
# 7         MIAMI FL            6454
# 1        AUSTIN TX            4896
# 10   ORANGE COUNTY            3982
# 5        DENVER CO            3825
# 8     NASHVILLE TN            3010
# 13   SACRAMENTO CA            2367
# 11      PHOENIX AZ            2064
# 17       TUCSON AZ            1931
# 12   PITTSBURGH PA            1313

# %%
# Merged City data into aggreagated transaction data frame to further confirm hypothesis. 
aggregated_trancity_data = pd.merge(aggregated_tran_data, city_data, on = 'City', how = 'left')

print(aggregated_trancity_data)
# Out:
#               City  Transaction ID   Population      Users
# 0      NEW YORK NY           99885   8,405,837    302,149
# 1       CHICAGO IL           56625   1,955,130    164,468
# 2   LOS ANGELES CA           48033   1,595,037    144,132
# 3    WASHINGTON DC           43737     418,859    127,001
# 4        BOSTON MA           29692     248,968     80,021
# 5     SAN DIEGO CA           20488     959,307     69,995
# 6   SILICON VALLEY            8519   1,177,609     27,247
# 7       SEATTLE WA            7997     671,238     25,063
# 8       ATLANTA GA            7557     814,885     24,701
# 9        DALLAS TX            7017     942,908     22,157
# 10        MIAMI FL            6454   1,339,155     17,675
# 11       AUSTIN TX            4896     698,371     14,978
# 12   ORANGE COUNTY            3982   1,030,185     12,994
# 13       DENVER CO            3825     754,233     12,421
# 14    NASHVILLE TN            3010     327,225      9,270
# ...

# %%
# Grouped by 'City' and 'Company', counted 'Transaction ID', the sum of 'KM Travelled', and Profit by taking
# 'Price Charged' - 'Cost of Trip'.
aggregated_data = new_data.groupby(['City', 'Company']).agg({'Transaction ID': 'count', 'KM Travelled': 'sum', 'Price Charged': lambda x: (x - new_data['Cost of Trip']).sum()}).reset_index()

# Sorted values by 'Company' and 'Transaction ID'.
aggregated_data = aggregated_data.sort_values(by = ['Company', 'Transaction ID'], ascending = [False, False])

# Renamed to 'Profit'
aggregated_data = aggregated_data.rename(columns = {'Price Charged': 'Profit'})

# Changed format of 'Profit' printed.
aggregated_data['Profit'] = aggregated_data['Profit'].apply(lambda x: '{:,.2f}'.format(x))

print(aggregated_data)
# Out:
#               City     Company  Transaction ID  KM Travelled         Profit
# 19     NEW YORK NY  Yellow Cab           85918    1932842.47  26,451,080.77
# 7       CHICAGO IL  Yellow Cab           47264    1070978.26   3,068,590.93
# 37   WASHINGTON DC  Yellow Cab           40045     906038.71   3,299,103.81
# 13  LOS ANGELES CA  Yellow Cab           28168     639078.88   3,285,976.58
# 5        BOSTON MA  Yellow Cab           24506     552454.67   1,506,717.57
# 29    SAN DIEGO CA  Yellow Cab            9816     219799.82     949,273.70
# 1       ATLANTA GA  Yellow Cab            5795     128928.59     746,382.81
# 9        DALLAS TX  Yellow Cab            5637     127392.79   1,104,003.15
# 31      SEATTLE WA  Yellow Cab            5265     118903.62     491,903.52
# 33  SILICON VALLEY  Yellow Cab            4722     107172.36     976,454.74
# 15        MIAMI FL  Yellow Cab            4452     100773.72     596,000.05
# ...

# %% [markdown]
# **Results of Hypothesis 2: Yellow Cab company had a higher number of Transaction IDs, KM Travelled, and Profit due to the EDA done regarding Hypothesis 2. It held true that high number of transactions leads to a higher number of cab users within the city but the disparity between Yellow Cab and Pink Cab companies was astonishing by analzing the Profit section, which took Price Charged - Cost of Trip. At the end of this Hypothesis we recommend investing into Yellow Cab company due to the customer attention which is apparent in Transaction IDs and Profit.**

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **Hypothesis 3: Based on a regression analysis using the variables 'KM Travelled' and 'Profit', it is anticipated that the Yellow Cab company will maintain higher profitability compared to the Pink Cab company.**

# %%
new_data.head(10)
# Out:
#    Transaction ID  Customer ID Payment_Mode  Date of Travel   Company  \
# 0        10000011        29290         Card        42377.00  Pink Cab
# 1        10000012        27703         Card        42375.00  Pink Cab
# 2        10000013        28712         Cash        42371.00  Pink Cab
# 3        10000014        28020         Cash        42376.00  Pink Cab
# 4        10000015        27182         Card        42372.00  Pink Cab
# 5        10000016        27318         Cash        42376.00  Pink Cab
# 6        10000017        33788         Card        42372.00  Pink Cab
# 7        10000018        34106         Card        42376.00  Pink Cab
# 8        10000019        59799         Cash        42381.00  Pink Cab
# 9        10000020        57982         Cash        42375.00  Pink Cab
#
#          City  KM Travelled  Price Charged  Cost of Trip Gender  Age  \
# 0  ATLANTA GA         30.45         370.95        313.63   Male   28
# ...

# %%
# Made a new column 'Profit' by taking the same steps as before.
new_data['Profit'] = new_data['Price Charged'] - new_data['Cost of Trip']

# Got the sum of 'KM Travelled' for each Customer ID for the two cab companies. 
profit_km_data = new_data.groupby(['Customer ID', 'Company'])['KM Travelled'].sum().reset_index()

# Got the sum of 'Profit' generated from each Customer ID for the two cab companies.
profit_km_data['Profit'] = new_data.groupby(['Customer ID', 'Company'])['Profit'].sum().values

# %%
profit_km_data.head(10)
# Out:
#    Customer ID     Company  KM Travelled   Profit
# 0            1    Pink Cab        125.52   873.16
# 1            1  Yellow Cab        582.81  7550.60
# 2            2    Pink Cab         96.28   600.41
# 3            2  Yellow Cab        836.09 11370.90
# 4            3    Pink Cab        191.70   666.09
# 5            3  Yellow Cab        845.71 10994.24
# 6            4    Pink Cab         38.15   177.32
# 7            4  Yellow Cab        608.77  7870.54
# 8            5    Pink Cab        153.05   577.18
# 9            5  Yellow Cab        579.03  9311.23

# %%
profit_km_data.head(-10)
# Out:
#        Customer ID     Company  KM Travelled   Profit
# 0                1    Pink Cab        125.52   873.16
# 1                1  Yellow Cab        582.81  7550.60
# 2                2    Pink Cab         96.28   600.41
# 3                2  Yellow Cab        836.09 11370.90
# 4                3    Pink Cab        191.70   666.09
# ...            ...         ...           ...      ...
# 72211        59993    Pink Cab         19.95    98.41
# 72212        59993  Yellow Cab        246.62   437.78
# 72213        59994    Pink Cab         78.88   166.73
# 72214        59994  Yellow Cab        248.93   989.09
# 72215        59995    Pink Cab         17.18     3.44
#
# [72216 rows x 4 columns]

# %%
# Split the data into separate dataframes for each company.
yellow_cab_data = new_data[new_data['Company'] == 'Yellow Cab']
pink_cab_data = new_data[new_data['Company'] == 'Pink Cab']

# Created separate regression models for each company.
yellow_cab_model = LinearRegression()
pink_cab_model = LinearRegression()

# Fit the regression models using 'Profit' and 'KM Travelled' as predictors.
yellow_cab_model.fit(yellow_cab_data[['Profit', 'KM Travelled']], yellow_cab_data['Profit'])
pink_cab_model.fit(pink_cab_data[['Profit', 'KM Travelled']], pink_cab_data['Profit'])

# Predicted future profits for each company.
future_profit_yellow_cab = yellow_cab_model.predict(yellow_cab_data[['Profit', 'KM Travelled']])
future_profit_pink_cab = pink_cab_model.predict(pink_cab_data[['Profit', 'KM Travelled']])

# %%
# Created a range of x values for plotting.
x = yellow_cab_data['KM Travelled']

# Plot the actual profits.
plt.scatter(x, yellow_cab_data['Profit'], color = 'orange', label = 'Actual Profits (Yellow Cab)')

# Plot the predicted future profits.
plt.plot(x, future_profit_yellow_cab, color = 'black', label = 'Predicted Future Profits (Yellow Cab)')

# Add labels and title to the plot.
plt.xlabel('KM Travelled')
plt.ylabel('Profit')
plt.title('Predicted Future Profits for Yellow Cab')
plt.legend()

plt.show()

# %%
# Created a range of x values for plotting for Pink Company.
x = pink_cab_data['KM Travelled']

# Plot the actual profits.
plt.scatter(x, pink_cab_data['Profit'], color ='orange', label = 'Actual Profits (Pink Cab)')

# Plot the predicted future profits.
plt.plot(x, future_profit_pink_cab, color = 'black', label = 'Predicted Future Profits (Pink Cab)')

# Add labels and title to the plot.
plt.xlabel('KM Travelled')
plt.ylabel('Profit')
plt.title('Predicted Future Profits for Pink Cab')
plt.legend()

plt.show()

# %% [markdown]
# **Results of Hypothesis 3: As shown by the regression analysis, Yellow Cab will continue to make more profit on high KM riders than Pink Cab due to each Customer ID primarily having more of a higher aggregated KM Travelled for Yellow Cab.**

# %% [markdown]
# **--------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **Hypothesis 4: Regrssion Analysis between 'Cost of Trip' and 'KM Travelled' to visualize who will have more expenses in the future. I assume 'Cost of Trip' is a collective group of expenses a company has in order to find the right 'Price Charged' to charge to a Customer. I believe the Pink Cab Company will have less expenses than Yellow Cab Company.**

# %%
# Aggregated 'Cost of Trip' expense account and 'KM Travelled' then grouped by 'Customer ID' and 'Company'.
company_expense = new_data.groupby(['Customer ID', 'Company']).agg({'Cost of Trip': 'sum', 'KM Travelled': 'sum'}).reset_index()

company_expense.head(10)
# Out:
#    Customer ID     Company  Cost of Trip  KM Travelled
# 0            1    Pink Cab       1413.32        125.52
# 1            1  Yellow Cab       7653.05        582.81
# 2            2    Pink Cab        994.30         96.28
# 3            2  Yellow Cab      11027.25        836.09
# 4            3    Pink Cab       2188.53        191.70
# 5            3  Yellow Cab      10979.49        845.71
# 6            4    Pink Cab        385.31         38.15
# 7            4  Yellow Cab       7875.37        608.77
# 8            5    Pink Cab       1695.52        153.05
# 9            5  Yellow Cab       7727.04        579.03

# %%
# Split the data into separate dataframes for Yellow Cab specifically. 
yellow_cab_data2 = company_expense[company_expense['Company'] == 'Yellow Cab']

# Created a regression model for Yellow Cab.
yellow_cab_model2 = LinearRegression()

# Fit the regression model using 'Cost of Trip' and 'KM Travelled' as predictors.
yellow_cab_model2.fit(yellow_cab_data2[['Cost of Trip', 'KM Travelled']], yellow_cab_data2['Cost of Trip'])

# Predict future expenses for Yellow Cab.
future_expense_yellow_cab = yellow_cab_model2.predict(yellow_cab_data2[['Cost of Trip', 'KM Travelled']])

# Split the data into separate dataframes for Pink Cab.
pink_cab_data2 = company_expense[company_expense['Company'] == 'Pink Cab']

# Create a regression model for Pink Cab.
pink_cab_model2 = LinearRegression()

# Fit the regression model using 'Cost of Trip' and 'KM Travelled' as predictors.
pink_cab_model2.fit(pink_cab_data2[['Cost of Trip', 'KM Travelled']], pink_cab_data2['Cost of Trip'])

# Predict future expenses for Pink Cab.
future_expense_pink_cab = pink_cab_model2.predict(pink_cab_data2[['Cost of Trip', 'KM Travelled']])

# Determine the common axis limits in order to plot on the same scale.
x_min = min(yellow_cab_data2['KM Travelled'].min(), pink_cab_data2['KM Travelled'].min())
x_max = max(yellow_cab_data2['KM Travelled'].max(), pink_cab_data2['KM Travelled'].max())
y_min = min(future_expense_yellow_cab.min(), future_expense_pink_cab.min())
y_max = max(future_expense_yellow_cab.max(), future_expense_pink_cab.max())

# Plot both regression lines on the same scale values.
plt.figure(figsize = (10, 6))
sns.lineplot(x = yellow_cab_data2['KM Travelled'], y = future_expense_yellow_cab, label = 'Yellow Cab', color = 'orange')
sns.lineplot(x = pink_cab_data2['KM Travelled'], y = future_expense_pink_cab, label = 'Pink Cab', color = 'black')

plt.xlabel('KM Travelled')
plt.ylabel('Future Expense')
plt.title('Regression Analysis for Cab Expenses')
plt.legend()

# Set the common axis limits.
plt.xlim(x_min, x_max)
plt.ylim(y_min, y_max)

plt.show()

# %%
# Wanted to see difference in Customer count for each company to see the reason why such a disparity between 
# expenses exist.
customer_count = new_data.groupby('Company')['Customer ID'].nunique().reset_index()

customer_count.columns = ['Company', 'Customer Count']

print(customer_count)
# Out:
#       Company  Customer Count
# 0    Pink Cab           32330
# 1  Yellow Cab           39896

# %%
# Wanted to see the difference in Transaction count for the same reason above.
transaction_count = new_data.groupby('Company')['Transaction ID'].count().reset_index()

transaction_count.columns = ['Company', 'Transaction Count']

print(transaction_count)
# Out:
#       Company  Transaction Count
# 0    Pink Cab              84711
# 1  Yellow Cab             274681

# %%
new_data['Profit'] = new_data['Price Charged'] - new_data['Cost of Trip']

# Calculated the sum of profit for each company using group by.
company_profit = new_data.groupby('Company')['Profit'].sum()

print(company_profit)
# Out:
# Company
# Pink Cab      5307328.32
# Yellow Cab   44020373.17
# Name: Profit, dtype: float64

# %% [markdown]
# **Results of Hypothesis 4: Although Pink Company will have less expenses in the future, the Yellow Cab company has more expenses due to high transaction count and 44 million in profit compared to Pink Cab's 5.3 million in profit. If Pink Cab is able to target areas with high transaction counts and take some of Yellow Cab's business away, they will make a higher profit margin than Yellow Cab by keeping there expenses down but increasing Profits due to high targeting of Customer IDs with high Transaction IDs. With Pink Company you will experience more growth within the company compared to the high profile Yellow Cab company.**

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **Hypothesis 5: With everything taken into account we will analyze the sample size 35-45 year olds and create a regression analysis based off the variables 'Profit' and 'KM Travelled' then kept the sample as identical as possible.**

# %%
# Filter the data for incomes between 0 and 10000 to see if they should be used in the
# analysis or not. This is important to see if they will cause signifigance in the analysis.
income_test_df = new_data[(new_data['Income (USD/Month)'] >= 0) & (new_data['Income (USD/Month)'] <= 10000)]

# This directly affects the analysis by seeing if the low-income housing market is evenly
# dispersed or not. 
income_test_df.head(-20)
# Out:
#         Transaction ID  Customer ID Payment_Mode  Date of Travel     Company  \
# 1             10000012        27703         Card        42375.00    Pink Cab
# 4             10000015        27182         Card        42372.00    Pink Cab
# 9             10000020        57982         Cash        42375.00    Pink Cab
# 12            10000023        59007         Card        42380.00    Pink Cab
# 13            10000024        58215         Cash        42375.00    Pink Cab
# ...                ...          ...          ...             ...         ...
# 440034        10440045        53263         Card             NaN         NaN
# 440039        10440050        51923         Card        43105.00  Yellow Cab
# 440044        10440055        52446         Card        43107.00  Yellow Cab
# 440048        10440059        52638         Card        43106.00  Yellow Cab
# 440050        10440061        53271         Card        43105.00  Yellow Cab
#
# ...

# %%
# Counted the number of 'Transaction ID' for each company in the 0-10000 income range.
company_count = income_test_df.groupby('Company')['Transaction ID'].count()

# Print the company count.
print(company_count)
# Out:
# Company
# Pink Cab      26702
# Yellow Cab    86008
# Name: Transaction ID, dtype: int64

# %% [markdown]
# **To address the uneven distribution of data, I will refine my analysis by selecting a sample group and predicting the profits for each company within the excluded income range. My goal is to identify the middle-class segment where both companies can thrive in their business operations.**

# %%
# Filtered the data based on the sample age range (35-45).
sample_analysis = new_data[(new_data['Age'] >= 35) & (new_data['Age'] <= 45)]

# Aggregated 'KM Travelled' and 'Profit' and grouped by 'Company' and 'Customer ID' columns.
sample_analysis = sample_analysis.groupby(['Customer ID', 'Company']).agg({'KM Travelled': 'sum', 'Profit': 'sum'}).reset_index()

# Print the result.
print(sample_analysis)
# Out:
#        Customer ID     Company  KM Travelled  Profit
# 0                1    Pink Cab        125.52  873.16
# 1                1  Yellow Cab        582.81 7550.60
# 2               12    Pink Cab        135.55  826.99
# 3               12  Yellow Cab        573.25 8005.68
# 4               15    Pink Cab         74.69  486.02
# ...            ...         ...           ...     ...
# 17489        59988  Yellow Cab        158.54  327.52
# 17490        59993    Pink Cab         19.95   98.41
# 17491        59993  Yellow Cab        246.62  437.78
# 17492        59999    Pink Cab         50.48   65.83
# 17493        59999  Yellow Cab        113.15  283.42
#
# [17494 rows x 4 columns]

# %%
# Wanted to see the disperse amongst the sample size by counting 'Customer ID' instead.
sample_count = sample_analysis.groupby('Company')['Customer ID'].count()

# Result shows a similar count compared to the company_count which confirms hypothesis's track.
print(sample_count)
# Out:
# Company
# Pink Cab      7832
# Yellow Cab    9662
# Name: Customer ID, dtype: int64

# %%
# Filter the data for Pink Cab.
pink_cab_data3 = sample_analysis[sample_analysis['Company'] == 'Pink Cab']

# Filter the data for Yellow Cab.
yellow_cab_data3 = sample_analysis[sample_analysis['Company'] == 'Yellow Cab']

# Create separate regression models for Pink Cab and Yellow Cab.
pink_cab_model3 = LinearRegression()
yellow_cab_model3 = LinearRegression()

# Fit the regression models using 'Profit' and 'KM Travelled' as predictors.
pink_cab_model3.fit(pink_cab_data3[['Profit', 'KM Travelled']], pink_cab_data3['Profit'])
yellow_cab_model3.fit(yellow_cab_data3[['Profit', 'KM Travelled']], yellow_cab_data3['Profit'])

# Predict the profits for Pink Cab and Yellow Cab.
pink_cab_predicted_profits = pink_cab_model3.predict(pink_cab_data3[['Profit', 'KM Travelled']])
yellow_cab_predicted_profits = yellow_cab_model3.predict(yellow_cab_data3[['Profit', 'KM Travelled']])

# Plot the regression lines for Pink Cab and Yellow Cab.
plt.figure(figsize = (10, 6))
sns.scatterplot(x = 'KM Travelled', y = 'Profit', data = pink_cab_data3, alpha = 1, s = 50, label = 'Pink Cab')
sns.scatterplot(x = 'KM Travelled', y = 'Profit', data = yellow_cab_data3, alpha = 0.3, s = 50, label = 'Yellow Cab')
sns.lineplot(x = pink_cab_data3['KM Travelled'], y = pink_cab_predicted_profits, color = 'black')
sns.lineplot(x = yellow_cab_data3['KM Travelled'], y = yellow_cab_predicted_profits, color = 'orange')

# Plotted labels for visual.
plt.xlabel('KM Travelled')
plt.ylabel('Profit')
plt.title('Regression Analysis: Profit vs. KM Travelled')
plt.legend()
plt.show()

# %% [markdown]
# **Results of Hypothesis 5: Invest in Yellow Cab company. Through this analysis I provided fair parameters for both companies to adhere to and the result of the regression analysis shows that even if the sample may be equal in Customer IDs for both company, Yellow Cab company will continue to get more profits in the future.**

# %% [markdown]
# **------------------------------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# **EDA Recommendation:**
#
# Investing in the Yellow Cab Company is recommended due to its current and projected higher business volume compared to the Pink Cab Company, even though they share a significant number of customers. The analysis showed that Yellow Cab had higher transaction counts, higher KM traveled, and higher profits, indicating its stronger presence and potential for business success.

# %% [markdown]
# **Hypothesis Results:**
#
# Hypothesis 1:
# Based on the analysis of the age group 35-45, Yellow Cab demonstrated higher revenues and transaction volumes compared to Pink Cab.
# Conclusion: Investing in Yellow Cab is recommended due to its stronger customer base and potential for business success.
#
# Hypothesis 2:
# Yellow Cab exhibited higher transaction counts, KM traveled, and profits compared to Pink Cab.
# The analysis indicated that higher transaction volumes lead to higher profitability.
# Conclusion: Yellow Cab has a stronger financial performance and higher potential for generating profits.
#
# Hypothesis 3:
# Regression analysis revealed that Yellow Cab is likely to continue making more profit from customers who travel longer distances (high KM riders) compared to Pink Cab.
# The aggregated KM traveled per Customer ID was higher for Yellow Cab.
# Conclusion: Yellow Cab has a better opportunity to generate profits from customers with longer trips.
#
# Hypothesis 4:
# While Pink Cab may have lower projected future expenses, Yellow Cab demonstrated significantly higher profits due to its higher transaction count and revenue.
# Pink Cab can potentially increase profit margins by strategically targeting areas with high transaction counts and attracting customers from Yellow Cab.
# Conclusion: Yellow Cab currently has a stronger financial position, but Pink Cab has growth potential if it strategically targets high transaction areas.
#
# Hypothesis 5:
# The regression analysis consistently supported investing in Yellow Cab, projecting higher profits in the future compared to Pink Cab.
# Yellow Cab exhibited more promising growth potential and returns based on the analysis.
# Conclusion: Investing in Yellow Cab is recommended for higher returns and long-term business success.
